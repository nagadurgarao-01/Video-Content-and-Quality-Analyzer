# %%
import pandas as pd
df= pd.read_csv("project_videos/data/Master AI & ML Video Explanation Benchmark Dataset (205 Videos) - Untitled.csv")

# %%
print(df.shape)
print(df.head())
print(df.columns)
# Out:
# (205, 25)
#         ID               Category                      Channel  \
# 0  VID-001  Machine Learning (ML)                  3Blue1Brown
# 1  VID-002  Machine Learning (ML)                  3Blue1Brown
# 2  VID-003  Machine Learning (ML)  StatQuest with Josh Starmer
# 3  VID-004  Machine Learning (ML)  StatQuest with Josh Starmer
# 4  VID-005  Machine Learning (ML)  StatQuest with Josh Starmer
#
#                                                Title  \
# 0  But what is a neural network? | Deep learning ...
# 1  Gradient descent, how neural networks learn | ...
# 2          A Gentle Introduction to Machine Learning
# 3   Machine Learning Fundamentals: Bias and Variance
# 4    Machine Learning Fundamentals: Cross Validation
#
#                                           URL Duration   Views  \
# 0  http://www.youtube.com/watch?v=aircAruvnKk    18:40  24.2M+
# 1  http://www.youtube.com/watch?v=IHZwWFHWa-w    20:33   9.5M+
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 205 non-null    object
#  1   Category           205 non-null    object
#  2   Channel            205 non-null    object
#  3   Title              205 non-null    object
#  4   URL                205 non-null    object
#  5   Duration           205 non-null    object
#  6   Views              205 non-null    object
#  7   Explanation_Type   205 non-null    object
#  8   Visuals            205 non-null    object
#  9   Examples           205 non-null    object
#  10  Analogies          205 non-null    object
#  11  Real_Life          205 non-null    object
#  12  Quality            205 non-null    object
#  13  Creator_Takeaways  205 non-null    object
#  14  Unnamed: 14        0 non-null      float64
#  15  Unnamed: 15        0 non-null      float64
# ...

# %%
df.isnull().sum()
# Out:
# ID                     0
# Category               0
# Channel                0
# Title                  0
# URL                    0
# Duration               0
# Views                  0
# Explanation_Type       0
# Visuals                0
# Examples               0
# Analogies              0
# Real_Life              0
# Quality                0
# Creator_Takeaways      0
# Unnamed: 14          205
# Unnamed: 15          205
# Unnamed: 16          205
# Unnamed: 17          205
# Unnamed: 18          205
# Unnamed: 19          205
# Unnamed: 20          205
# Unnamed: 21          205
# Unnamed: 22          205
# Unnamed: 23          205
# Unnamed: 24          205
# dtype: int64

# %%
df.describe(include="all")
# Out:
#              ID               Category         Channel  \
# count       205                    205             205
# unique      205                     11             107
# top     VID-001  Machine Learning (ML)  IBM Technology
# freq          1                     30              30
# mean        NaN                    NaN             NaN
# std         NaN                    NaN             NaN
# min         NaN                    NaN             NaN
# 25%         NaN                    NaN             NaN
# 50%         NaN                    NaN             NaN
# 75%         NaN                    NaN             NaN
# max         NaN                    NaN             NaN
#
#                                                     Title  \
# count                                                 205
# unique                                                205
# top     But what is a neural network? | Deep learning ...
# freq                                                    1
# ...

# %%
for column in df.columns:
    print("\n", column)
    print(df[column].head(5))
# Out:
#  ID
# 0    VID-001
# 1    VID-002
# 2    VID-003
# 3    VID-004
# 4    VID-005
# Name: ID, dtype: object
#
#  Category
# 0    Machine Learning (ML)
# 1    Machine Learning (ML)
# 2    Machine Learning (ML)
# 3    Machine Learning (ML)
# 4    Machine Learning (ML)
# Name: Category, dtype: object
#
#  Channel
# 0                    3Blue1Brown
# 1                    3Blue1Brown
# 2    StatQuest with Josh Starmer
# 3    StatQuest with Josh Starmer
# 4    StatQuest with Josh Starmer
# Name: Channel, dtype: object
#
#  Title
# 0    But what is a neural network? | Deep learning ...
# 1    Gradient descent, how neural networks learn | ...
# 2            A Gentle Introduction to Machine Learning
# 3     Machine Learning Fundamentals: Bias and Variance
# 4      Machine Learning Fundamentals: Cross Validation
# Name: Title, dtype: object
#
#  URL
# 0    http://www.youtube.com/watch?v=aircAruvnKk
# 1    http://www.youtube.com/watch?v=IHZwWFHWa-w
# ...

# %%
empty_columns = df.columns[df.isna().all()].tolist()

print("Empty columns:")
print(empty_columns)


df = df.drop(columns=empty_columns)

print("\nNew shape:", df.shape)
# Out:
# Empty columns:
# ['Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24']
#
# New shape: (205, 14)

# %%
df
# Out:
#           ID                              Category  \
# 0    VID-001                 Machine Learning (ML)
# 1    VID-002                 Machine Learning (ML)
# 2    VID-003                 Machine Learning (ML)
# 3    VID-004                 Machine Learning (ML)
# 4    VID-005                 Machine Learning (ML)
# ..       ...                                   ...
# 200  VID-201  Reinforcement Learning & Game Theory
# 201  VID-202       Computer Vision & Multimodal AI
# 202  VID-203       Computer Vision & Multimodal AI
# 203  VID-204       Computer Vision & Multimodal AI
# 204  VID-205           Advanced Retrieval & Search
#
#                                   Channel  \
# 0                             3Blue1Brown
# 1                             3Blue1Brown
# 2             StatQuest with Josh Starmer
# 3             StatQuest with Josh Starmer
# 4             StatQuest with Josh Starmer
# ..                                    ...
# 200                            Edan Meyer
# ...

# %%
missing = df.isnull().sum()

print(missing)
# Out:
# ID                   0
# Category             0
# Channel              0
# Title                0
# URL                  0
# Duration             0
# Views                0
# Explanation_Type     0
# Visuals              0
# Examples             0
# Analogies            0
# Real_Life            0
# Quality              0
# Creator_Takeaways    0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#              ID               Category         Channel  \
# count       205                    205             205
# unique      205                     11             107
# top     VID-001  Machine Learning (ML)  IBM Technology
# freq          1                     30              30
#
#                                                     Title  \
# count                                                 205
# unique                                                205
# top     But what is a neural network? | Deep learning ...
# freq                                                    1
#
#                                                URL Duration  Views  \
# count                                          205      205    205
# unique                                         205      192    166
# top     http://www.youtube.com/watch?v=aircAruvnKk    06:36  1.1M+
# freq                                             1        2      4
#
#                  Explanation_Type  \
# ...

# %%
for column in df.columns:
    print("\n", column)
    print(df[column].head(5))
# Out:
#  ID
# 0    VID-001
# 1    VID-002
# 2    VID-003
# 3    VID-004
# 4    VID-005
# Name: ID, dtype: object
#
#  Category
# 0    Machine Learning (ML)
# 1    Machine Learning (ML)
# 2    Machine Learning (ML)
# 3    Machine Learning (ML)
# 4    Machine Learning (ML)
# Name: Category, dtype: object
#
#  Channel
# 0                    3Blue1Brown
# 1                    3Blue1Brown
# 2    StatQuest with Josh Starmer
# 3    StatQuest with Josh Starmer
# 4    StatQuest with Josh Starmer
# Name: Channel, dtype: object
#
#  Title
# 0    But what is a neural network? | Deep learning ...
# 1    Gradient descent, how neural networks learn | ...
# 2            A Gentle Introduction to Machine Learning
# 3     Machine Learning Fundamentals: Bias and Variance
# 4      Machine Learning Fundamentals: Cross Validation
# Name: Title, dtype: object
#
#  URL
# 0    http://www.youtube.com/watch?v=aircAruvnKk
# 1    http://www.youtube.com/watch?v=IHZwWFHWa-w
# ...

# %%
df = df.drop_duplicates()

df["Title"] = df["Title"].fillna("")
df["Channel"] = df["Channel"].fillna("")
df["Examples"] = df["Examples"].fillna("")
df["Analogies"] = df["Analogies"].fillna("")
df["Visuals"] = df["Visuals"].fillna("")

# %%
text_columns = [
    "Title",
    "Explanation_Type",
    "Visuals",
    "Examples",
    "Analogies",
    "Real_Life",
    "Quality",
    "Creator_Takeaways"
]

for col in text_columns:
    df[col] = df[col].fillna("").astype(str)

# %%
def duration_to_seconds(duration):

    parts = duration.split(":")

    if len(parts) == 2:
        minutes, seconds = map(int, parts)
        return minutes * 60 + seconds

    if len(parts) == 3:
        hours, minutes, seconds = map(int, parts)
        return hours * 3600 + minutes * 60 + seconds

    return None

# %%
df["duration_seconds"] = df["Duration"].apply(duration_to_seconds)

# %%
def convert_views(x):

    x = str(x).replace("+", "").strip()

    if x.endswith("M"):
        return float(x[:-1]) * 1_000_000

    if x.endswith("K"):
        return float(x[:-1]) * 1_000

    return float(x)

# %%
df["views_numeric"] = df["Views"].apply(convert_views)

# %%
df["combined_text"] = (
    "Title: " + df["Title"] +
    "\nExplanation: " + df["Explanation_Type"] +
    "\nVisuals: " + df["Visuals"] +
    "\nExamples: " + df["Examples"] +
    "\nAnalogies: " + df["Analogies"] +
    "\nApplications: " + df["Real_Life"] +
    "\nQuality: " + df["Quality"] +
    "\nTakeaway: " + df["Creator_Takeaways"]
)

# %%
print(df["combined_text"].iloc[0])
# Out:
# Title: But what is a neural network? | Deep learning chapter 1
# Explanation: Mathematical & Geometric Intuition
# Visuals: Custom Manim animations; dynamic 28x28 pixel grid activations; colored weight synapses (green/red); layered node transformations.
# Examples: MNIST handwritten digit recognition focusing on handwritten '3's vs other digits.
# Analogies: Biological neurons firing vs mathematical dials/weights (0 to 1); layered abstraction hierarchy (pixels -> edges -> loops -> digits).
# Applications: Human visual cortex processing; speech recognition acoustic decomposition; YouTube recommendation algorithms.
# Quality: Pristine studio acoustics; calm, deliberate cadence (~130 wpm); subtle musical scoring; 1080p razor-sharp vector graphics.
# Takeaway: Hook with an intuitive mystery; never introduce formulas before visual intuition; break black boxes into modular components.

# %%
df["has_analogy"] = (
    df["Analogies"].str.len() > 10
).astype(int)

# %%
df["has_example"] = (
    df["Examples"].str.len() > 10
).astype(int)

# %%
df["has_visual"] = (
    df["Visuals"].str.len() > 10
).astype(int)

# %%
df["has_visual"] = (
    df["Visuals"].str.len() > 10
).astype(int)

# %%
df["has_math"] = df["combined_text"].str.contains(
    r"formula|equation|mathematical|calculus|derivation|geometry|gradient",
    case=False,
    regex=True
).astype(int)

# %%
df["has_code"] = df["combined_text"].str.contains(
    r"code|python|pytorch|tensorflow|programming|terminal|implementation",
    case=False,
    regex=True
).astype(int)

# %%
df["has_application"] = (
    df["Real_Life"].str.len() > 10
).astype(int)

# %%
print(df.shape)
print(df.columns.tolist())
# Out:
# (205, 23)
# ['ID', 'Category', 'Channel', 'Title', 'URL', 'Duration', 'Views', 'Explanation_Type', 'Visuals', 'Examples', 'Analogies', 'Real_Life', 'Quality', 'Creator_Takeaways', 'duration_seconds', 'views_numeric', 'combined_text', 'has_analogy', 'has_example', 'has_visual', 'has_math', 'has_code', 'has_application']

# %%
df.to_csv(
    "project_videos/data/processed/videos_clean.csv",
    index=False
)

print("Cleaned dataset saved successfully.")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.to_csv(
#       2     "project_videos/data/processed/videos_clean.csv",
#       3     index=False
#       4 )
#       6 print("Cleaned dataset saved successfully.")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
